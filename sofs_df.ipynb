# %%
import pandas as pd
import re

labels = pd.read_csv("sofs_tagging.csv")
labels.head()

with open("sofs_text.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

pattern = r"\n([A-Z][a-z]+ \d{1,2}, 1847)\n"
parts = re.split(pattern, raw_text)

dates = parts[1::2]
texts = parts[2::2]

text_df = pd.DataFrame({
    "chapter_id": range(len(texts)),
    "date": dates,
    "text": texts
})

df = text_df.merge(labels, on="chapter_id")
df.head()
# Out:
#    chapter_id         date                                               text  \
# 0           1  May 1, 1847  \n\nI heard Ma crying in the night when everyo...
# 1           2  May 3, 1847  \n\nI am crouched behind a rock at the side of...
# 2           3  May 6, 1847  \n\nWe left Ireland yesterday and have reached...
# 3           4  May 7, 1847  \n\nFrom a distance, the stone piers and docks...
# 4           5  May 8, 1847  \n\nAs we waited to board, I heard someone say...
#
#   theme_label
# 0   Community
# 1      Family
# 2    Survival
# 3     Illness
# 4    Survival
